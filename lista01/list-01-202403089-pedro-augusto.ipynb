# %% [markdown]
# **Questão 01 - Aprovado ou reprovado**
#
# Leia(Nota1 + Nota2 + Nota3)
#
# média <- (Nota1+Nota2+Nota3)/3
#
# Imprime (média)
#
# se média >=6 então
#
# Imprime (média)
# Imprime ("aprovado")
#
# senao
#
# Imprime (média)
# Imprime (reprovado)
#
# **Questão 02 - Arrecadação de jogos**
#
# Leia (nJogos)
#
# Enquanto (n < nJogos)
# Leia(ing)
# Leia(pP)
# Leia(pG)
# Leia(pA)
# Leia(pC)
#
# rendaTotal <- (ing * (pP / 100) * 1) + (ing * (pG / 100) * 5) + (ing * (pA / 100) * 10) + (ing * (pC / 100) * 20)
#
# Imprime("A RENDA DO JOGO N.n" " E = ", rendaTotal, "\n")
#
# **Questão 03 - Composição Inteira (+)**
#
# Imprime("Digite o primeiro número inteiro (centena): ")
#
# Leia(n1)
#
# Imprime("Digite o segundo número inteiro (dezena): ")
#
# Leia(n2)
#
# Imprime("Digite o terceiro número inteiro (unidade): ")
#
# Leia(n3)
#
# se n1 < 10 e n2 < 10 e n3 < 10 então
#
#
#    numero <- n1 * 100 + n2 * 10 + n3
#
#   se numero <> 0 então
#
#  Imprime(numero, ", ", quadrado, "\n")
#   senão
#
#   Imprime("DIGITO INVALIDO\n")
#
# senão
#
#   Imprime("DIGITO INVALIDO\n")
#
#
# **Questão 04 - Consumo de energia**
#
# Imprime ("salario mínimo: ")
#
# Leia (smin)
#
# Imprime ("kW gasto na residência: ")
#
# Leia (kwg)
#
# Imprime ("Desconto: ")
#
# Leia (%d)
#
# ckW <- (smin*0.7) / 100
#
# valor <- ckw * kW
#
# Desconto <- (valor * 10) / 100
#
# Novo <- valor - Desconto
#
# Imprime ("Cada kW e:", ckW)
#
# Imprime (" O valor a ser pago:", valor)
#
# Imprime ("Valor com desconto: ", PD, "% E:" Novo)
#
# **Questão 05 - Conta de Água**
#
# Imprime ("Digite o número da conta do cliente: ")
#
# Leia(contaCliente)
#
# Imprime("Digite o consumo de água em metros cúbicos: ")
#
# Leia(consumoAgua)
#
# Imprime("Digite o tipo do consumidor (R para residencial, C para comercial ou I para industrial): ")
#
# Leia(tipoConsumidor)
#
# se tipoConsumidor = "R"
#  então
#   valorConta <- 5.00 + 0.05 * consumoAgua
#
# senão
#
#  se tipoConsumidor = "C" então
#   se consumoAgua <= 80 então
#         valorConta <- 500.00
#   senão
#         valorConta <- 500.00 + 0.25 * (consumoAgua - 80)
#
# senão
# se tipoConsumidor = "I" então
#    se consumoAgua <= 100 então
#         valorConta <- 800.00
#   senão
#         valorConta <- 800.00 + 0.04 * (consumoAgua - 100)
#
#
# Imprime("CONTA = ", contaCliente, "\n")
# escreva("VALOR DA CONTA = ", valorConta, "\n")
#
# **Questão 06 - Conversões de Temperatura**
#
# Imprima(Digite °F: ")
#
# Leia(n)
#
# para i de 1 até n faça
#    Imprime("Digite a temperatura em Fahrenheit ", i, ": ")
#   Leia(temperaturaFahrenheit)
#
#   temperaturaCelsius <- (5 * (temperaturaFahrenheit - 32)) / 9
#
#
#   Imprime(temperaturaFahrenheit, " FAHRENHEIT EQUIVALE A ", temperaturaCelsius, " CELSIUS\n")
#
#
# **Questão 07 - Conversões para o Sistema Métrico**
#
# Imprime("Digite a temperatura em Fahrenheit: ")
#
# Leia(temperaturaFahrenheit)
#
# Imprime("Digite a quantidade de chuva em polegadas: ")
#
# Leia(polegadas)
#
# temperaturaCelsius <- (5 * temperaturaFahrenheit - 160) / 9
#
# milimetros <- polegadas * 25.4
#
# Imprime("O VALOR EM CELSIUS = ", temperaturaCelsius, "\n")
#
# Imprime("A QUANTIDADE DE CHUVA E = ", milimetros, "\n")
#
# **Questão 08 - Custo da Lata de Cerveja**
#
# Imprime("Digite o raio da lata (em metros): ")
#
# leia(raio)
#
# Imprime("Digite a altura da lata (em metros): ")
#
# leia(altura)
#
# areaCirculo <- PI * raio * raio
#
# areaLateral <- 2 * PI * raio * altura
#
# areaTotal <- 2 * areaCirculo + areaLateral
#
# custo <- areaTotal * 100.00
#
# Imprime("O VALOR DO CUSTO E = ", custo, "\n")
#
# **Questão 09 - Cálculo de Delta**
#
# Imprime("Digite o valor de a: ")
#
# leia(a)
#
# Imprime("Digite o valor de b: ")
#
# leia(b)
#
# Imprime("Digite o valor de c: ")
#
# leia(c)
#
# delta <- b * b - 4 * a * c
#
# Imprime("O valor do delta é: ", delta, "\n")
#
# **Questão 10 - Cálculo do Determinante de uma Matriz Quadrada de Duas Dimensões**
#
# Imprime("Digite o valor de a: ")
#
# leia(a)
#
# Imprime("Digite o valor de b: ")
#
# leia(b)
#
# Imprime("Digite o valor de c: ")
#
# leia(c)
#
# Imprime("Digite o valor de d: ")
#
# leia(d)
#
# determinante <- a * d - b * c
#
# Imprime("O VALOR DO DETERMINANTE E = ", determinante, "\n")
#
# **Questão 11 - Divisível por 3 e 5**
#
# Imprime("Digite um número inteiro: ")
#
# leia(numero)
#
#
# se numero % 3 = 0 e numero % 5 = 0 então
#
#   Imprime("O NUMERO E DIVISIVEL\n")
#
# senao
#
#   Imprime("O NUMERO NAO E DIVISIVEL\n")
#
#
# **Questão 12 - Locadora de Charretes**
#
# Constantes
#
# txpadrao = 10.00
#
# txadicional = 5.00
#
# horapadrao = 3.00
#
#
# Imprime("Digite o número de horas que a charrete foi utilizada: ")
#
# leia(horasUtilizadas)
#
#
# se
# horasUtilizadas >= horapadrao então
#   valorPagar <- txpadrao
#
# senao
#
#   valorPagar <- txpadrao + ((horapadrao - horasUtilizadas) * txadicional)
#
# Imprime("O VALOR A PAGAR E = ", valorPagar, "\n")
#
# **Questão 13 - Conversão de Nota em Conceito**
#
#
# Imprime("Digite a nota do aluno (entre 0 e 10): ")
#
# leia(nota)
#
# Conversão da nota para conceito
#
# se nota >= 9.0 então
#    conceito <- "A"
#
# senao
#
# se nota >= 7.5 então
#    conceito <- "B"
#
# senao
#
# se nota >= 6.0 então
#    conceito <- "C"
#
# senao
#
#   conceito <- "D"
#
# Imprime("NOTA = ", nota, " CONCEITO = ", conceito, "\n")
#
# **Questão 14 - Volume da Pirâmide de Base Hexagonal**
#
# Imprime("Digite a altura da pirâmide (em metros): ")
#
# leia(altura)
#
# Imprime("Digite o comprimento da aresta do hexágono (em metros): ")
#
# leia(aresta)
#
# areaBase <- (3 * aresta * aresta * √3 / 2
#
# volume <- (1/3) * areaBase * altura
#
# Imprime("O VOLUME DA PIRAMIDE E = ", volume, " METROS CUBICOS\n")
#
# **Questão 15 - Quadrado de pares**
#
# Imprime("Digite um valor inteiro N (5 < N < 2000): ")
#
# leia(N)
#
# Loop para encontrar e imprimir o quadrado de cada número par
# para i de 2 ate N passo 2 faca
#   inteiro quadrado
#   quadrado <- i * i
#   Imprime(i, "^2 = ", quadrado, "\n")
#
# **Questão 16 - Reajuste Salarial**
#
# Imprime("Digite o salário do funcionário: ")
#
# leia(salario)
#
# se salario <= 300.00 então
#   salarioReajustado <- salario * 1.5 // Reajuste de 50%
# senao
#    salarioReajustado <- salario * 1.3 // Reajuste de 30%
#
# Imprime("SALARIO COM REAJUSTE = ", salarioReajustado, "\n")
#
# **Questão 17 - Série de Pares**
#
# Imprime("Digite dois números inteiros separados por um espaço: ")
#
# leia(x, y)
#
# se x % 2 = 0 então
#
#   Se x for par, imprime uma sequência de y números pares iniciando com x
#    para i de 0 ate y-1 faca
#
#         Imprime(x + 2*i, " ")
#
#    Imprime("\n")
#
# senao
#
#   Se x não for par, imprime a mensagem "O PRIMEIRO NUMERO NAO E PAR"
#   Imprime("O PRIMEIRO NUMERO NAO E PAR\n")
#
# **Questão 18 - Soma de PA**
#
# Imprime("Digite o valor inicial da progressão aritmética: ")
#
# leia(a1)
#
# Imprime("Digite a razão da progressão aritmética: ")
# leia(r)
#
# Imprime("Digite o número de elementos da progressão: ")
#
# leia(n)
#
# soma <- 0
#
# para termo de a1 ate a1 + (n-1)*r passo r faca
#   soma <- soma + termo
#
# Imprime("A soma dos ", n, " primeiros termos da progressão aritmética é: ", soma, "\n")
#
# **Questão 19 - Somatório Simples**
#
# Imprime("Digite um número inteiro positivo maior que 1: ")
#
# leia(n)
#
# se n <= 1 então
#   Imprime("Numero invalido!\n")
#
# senao
#
#   Inicializa o valor de S
#
#   S <- 0
#
#   Calcula a soma da série
#   para k de 1 ate n faca
#
#         S <- S + 1.0/k
#
#   Imprime(S, "\n")
#
# **Questão 20 - Tempo em segundos**
#
# Imprime("Digite o valor em horas: ")
# leia(horas)
#
# Imprime("Digite o valor em minutos: ")
# leia(minutos)
#
# Imprime("Digite o valor em segundos: ")
#
# leia(segundos)
# tempoSegundos <- (horas * 3600) + (minutos * 60) + segundos
#
# Imprime("O TEMPO EM SEGUNDOS E = ", tempoSegundos, "\n")
